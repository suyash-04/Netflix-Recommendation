# %%
import pandas as pd
import numpy as np 
from tmdbv3api import TMDb
import json
import requests
from dotenv import load_dotenv
import os
from pathlib import Path
from tmdbv3api import Movie

# %%
dotenv_path = Path(os.getcwd()).parent / ".env"
load_dotenv(dotenv_path)
api_key = os.getenv("API_KEY")

# %%
tmdb = TMDb()
tmdb.api_key = api_key

tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x)
    if not result:  # If the result is an empty list, return 'unknown'
        return "unknown"
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.nan #

# %%
def get_director(x):
    if isinstance(x, float) or pd.isna(x):  # Check if x is NaN (float)
        return "unknown"
    elif " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]
    return "unknown"

# %%
def get_actor(x, num):
    # Ensure x is not NaN
    if pd.isna(x):
        return "unkown"
    
    # Split by the correct delimiter and get the last part (the actors' names)
    actors = x.split("screenplay); ")[-1].split(", ")
    
    # If there aren't enough actors, return NaN
    if len(actors) < num:
        return np.nan
    else:
        return actors[num - 1]

# %%
def preprocess(year):
    link = f"https://en.wikipedia.org/wiki/List_of_American_films_of_{year}"
    print(link)
    df1 = pd.read_html(link, header=0)[2]
    df2 = pd.read_html(link, header=0)[3]
    df3 = pd.read_html(link, header=0)[4]
    df4 = pd.read_html(link, header=0)[5]
    df = pd.concat([df1, df2, df3, df4], ignore_index=True)
    df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
    df = df[['Title','Cast and crew','genres']]
    df['director_name'] = df['Cast and crew'].map(lambda x: get_director(x))
    df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor(x,1))
    df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor(x,2))
    df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor(x,3))
    df = df.rename(columns={'Title':'movie_title'})
    df['movie_title'] = df['movie_title'].str.lower()

    new_df= df.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
    new_df['actor_1_name'] = new_df['actor_1_name'].replace(np.nan, 'unknown')
    new_df['actor_2_name'] = new_df['actor_2_name'].replace(np.nan, 'unknown')
    new_df['actor_3_name'] = new_df['actor_3_name'].replace(np.nan, 'unknown')
    new_df['genres'] = new_df['genres'].replace(np.nan, 'unknown')
    new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' '+ new_df['actor_3_name'] + ' '+ new_df['director_name'] +' ' + new_df['genres']
 
    return new_df

# %%
df_2018 = preprocess(2018)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2018

# %%
df_2019 = preprocess(2019)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2019

# %%
df_2020 = preprocess(2020)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2020

# %%
df_2021 = preprocess(2021)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2021

# %%
df_2022 = preprocess(2022)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2022

# %%
df_2023  = preprocess(2023)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2023

# %%
df_2024 = preprocess(2024)
# Out:
# https://en.wikipedia.org/wiki/List_of_American_films_of_2024

# %%
df = pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022,df_2023,df_2024], ignore_index= True)
# Out:
# (2294, 7)

# %%
old = pd.read_csv('../artifacts/new_data.csv')
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
new = pd.concat([old , df] , ignore_index= True)
new
# Out:
#                                           director_name     actor_1_name  \
# 0                                         James Cameron      CCH Pounder
# 1                                        Gore Verbinski      Johnny Depp
# 2                                            Sam Mendes  Christoph Waltz
# 3                                     Christopher Nolan        Tom Hardy
# 4                                           Doug Walker      Doug Walker
# ...                                                 ...              ...
# 7718                                    Rachel Morrison     Ryan Destiny
# 7719                                     Michael Gracey  Robbie Williams
# 7720                                       Halina Reijn    Nicole Kidman
# 7721  Michael Schwartz, Tyler Nilson (directors/scre...    Héctor Medina
# 7722                              Matthew John Lawrence      Molly Brown
#
#              actor_2_name          actor_3_name  \
# 0        Joel David Moore             Wes Studi
# 1           Orlando Bloom        Jack Davenport
# 2            Rory Kinnear      Stephanie Sigman
# 3          Christian Bale  Joseph Gordon-Levitt
# 4              Rob Walker               unknown
# ...                   ...                   ...
# 7718    Brian Tyree Henry            Judy Greer
# 7719         Jonno Davies       Steve Pemberton
# 7720     Harris Dickinson          Sophie Wilde
# 7721         Adria Arjona     Eros de la Puente
# 7722  Jeffrey Dean Morgan           Billy Burke
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 7718                    History Drama
# 7719               Music Comedy Drama
# 7720                            Drama
# 7721                            Drama
# 7722                    Horror Comedy
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7718                                    The Fire Inside
# 7719                                         Better Man
# 7720                                           Babygirl
# 7721                                         Los Frikis
# 7722                                   Bloody Axe Wound
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7718  Ryan Destiny Brian Tyree Henry Judy Greer Rach...
# 7719  Robbie Williams Jonno Davies Steve Pemberton M...
# 7720  Nicole Kidman Harris Dickinson Sophie Wilde Ha...
# 7721  Héctor Medina Adria Arjona Eros de la Puente M...
# 7722  Molly Brown Jeffrey Dean Morgan Billy Burke Ma...
#
# [7723 rows x 7 columns]

# %%
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)
new
# Out:
#                                           director_name     actor_1_name  \
# 0                                         James Cameron      CCH Pounder
# 1                                        Gore Verbinski      Johnny Depp
# 2                                            Sam Mendes  Christoph Waltz
# 3                                     Christopher Nolan        Tom Hardy
# 4                                           Doug Walker      Doug Walker
# ...                                                 ...              ...
# 7718                                    Rachel Morrison     Ryan Destiny
# 7719                                     Michael Gracey  Robbie Williams
# 7720                                       Halina Reijn    Nicole Kidman
# 7721  Michael Schwartz, Tyler Nilson (directors/scre...    Héctor Medina
# 7722                              Matthew John Lawrence      Molly Brown
#
#              actor_2_name          actor_3_name  \
# 0        Joel David Moore             Wes Studi
# 1           Orlando Bloom        Jack Davenport
# 2            Rory Kinnear      Stephanie Sigman
# 3          Christian Bale  Joseph Gordon-Levitt
# 4              Rob Walker               unknown
# ...                   ...                   ...
# 7718    Brian Tyree Henry            Judy Greer
# 7719         Jonno Davies       Steve Pemberton
# 7720     Harris Dickinson          Sophie Wilde
# 7721         Adria Arjona     Eros de la Puente
# 7722  Jeffrey Dean Morgan           Billy Burke
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 7718                    History Drama
# 7719               Music Comedy Drama
# 7720                            Drama
# 7721                            Drama
# 7722                    Horror Comedy
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7718                                    The Fire Inside
# 7719                                         Better Man
# 7720                                           Babygirl
# 7721                                         Los Frikis
# 7722                                   Bloody Axe Wound
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7718  Ryan Destiny Brian Tyree Henry Judy Greer Rach...
# 7719  Robbie Williams Jonno Davies Steve Pemberton M...
# 7720  Nicole Kidman Harris Dickinson Sophie Wilde Ha...
# 7721  Héctor Medina Adria Arjona Eros de la Puente M...
# 7722  Molly Brown Jeffrey Dean Morgan Billy Burke Ma...
#
# [7706 rows x 7 columns]

# %%
new.to_csv('../artifacts/final_data.csv',index=False)

# %%
old = pd.read_csv('../artifacts/final_data.csv')
old.tail()
# Out:
#                                           director_name     actor_1_name  \
# 7701                                    Rachel Morrison     Ryan Destiny
# 7702                                     Michael Gracey  Robbie Williams
# 7703                                       Halina Reijn    Nicole Kidman
# 7704  Michael Schwartz, Tyler Nilson (directors/scre...    Héctor Medina
# 7705                              Matthew John Lawrence      Molly Brown
#
#              actor_2_name       actor_3_name              genres  \
# 7701    Brian Tyree Henry         Judy Greer       History Drama
# 7702         Jonno Davies    Steve Pemberton  Music Comedy Drama
# 7703     Harris Dickinson       Sophie Wilde               Drama
# 7704         Adria Arjona  Eros de la Puente               Drama
# 7705  Jeffrey Dean Morgan        Billy Burke       Horror Comedy
#
#            movie_title                                               comb
# 7701   the fire inside  Ryan Destiny Brian Tyree Henry Judy Greer Rach...
# 7702        better man  Robbie Williams Jonno Davies Steve Pemberton M...
# 7703          babygirl  Nicole Kidman Harris Dickinson Sophie Wilde Ha...
# 7704        los frikis  Héctor Medina Adria Arjona Eros de la Puente M...
# 7705  bloody axe wound  Molly Brown Jeffrey Dean Morgan Billy Burke Ma...
